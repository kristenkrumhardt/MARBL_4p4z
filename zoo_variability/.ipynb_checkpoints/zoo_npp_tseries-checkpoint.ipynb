# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import os
from glob import glob
#from collections import OrderedDict
import xarray as xr
import numpy as np
#import dask
#from ncar_jobqueue import NCARCluster
import esmlab
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
from scipy import stats
import pop_tools 

from statistics import mean
from matplotlib import style
from scipy import stats
import matplotlib.path as mpath
#style.use('ggplot')
# Out:
# Cannot write to data cache folder '/glade/p/cesmdata/cseg'. Will not be able to download remote data files. Use environment variable 'CESMDATAROOT' to specify another directory.

# %% [markdown]
# ### Get the CESM tseries files

# %% [markdown]
# #### get short-lived (71 d) zoo4 run

# %%
case = 'g.e22a06.G1850ECOIAF_JRA_PHYS_DEV.TL319_g17.4p4z.zoo4lowmort'
path = '/glade/scratch/kristenk/archive/' + case + '/ocn/proc/tseries/year_1'
variables = ['diatC', 'coccoC','spC','diazC','zoo1C','zoo2C','zoo3C','zoo4C','IFRAC','PD','Fe']
variables = variables + ['diatChl','spChl','diazChl','coccoChl']

# %%
# %%time
ds_list = []
print(f'reading {case}')
ds = xr.Dataset()

for v in variables:  
    print(v)
    files = sorted(glob(f'{path}/{case}.annual.{v}.????-????.nc'))       
    dsv=xr.open_mfdataset(files, data_vars="minimal", coords='minimal', compat="override", parallel=True, concat_dim="time",
                       drop_variables=["transport_components", "transport_regions"], decode_times=True)
    
    ds = xr.merge((ds, dsv))
    ds_list.append(ds)
# Out:
# reading g.e22a06.G1850ECOIAF_JRA_PHYS_DEV.TL319_g17.4p4z.zoo4lowmort
# diatC
# coccoC
# spC
# diazC
# zoo1C
# zoo2C
# zoo3C
# zoo4C
# IFRAC
# PD
# Fe
# diatChl
# spChl
# diazChl
# coccoChl
# CPU times: user 3.78 s, sys: 627 ms, total: 4.4 s
# Wall time: 6.97 s

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:          (nlat: 384, nlon: 320, time: 20, z_t: 60, z_t_150m: 15)
# Coordinates:
#     TLAT             (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#     TLONG            (nlat, nlon) float64 dask.array<chunksize=(384, 320), meta=np.ndarray>
#   * z_t              (z_t) float64 500.0 1.5e+03 2.5e+03 ... 5.125e+05 5.375e+05
#   * time             (time) object 0042-12-31 00:00:00 ... 0061-12-31 00:00:00
# Dimensions without coordinates: nlat, nlon, z_t_150m
# Data variables:
#     KMT              (time, nlat, nlon) float64 dask.array<chunksize=(20, 384, 320), meta=np.ndarray>
#     dz               (time, z_t) float32 dask.array<chunksize=(20, 60), meta=np.ndarray>
#     TAREA            (time, nlat, nlon) float64 dask.array<chunksize=(20, 384, 320), meta=np.ndarray>
#     diatC            (time, z_t_150m, nlat, nlon) float32 dask.array<chunksize=(20, 15, 384, 320), meta=np.ndarray>
# ...

# %% [markdown]
# #### get longer-lived (500 d) zoo4 run

# %%
case = 'g.e22a06.G1850ECOIAF_JRA_PHYS_DEV.TL319_g17.4p4z.zoo4both'
path = '/glade/scratch/kristenk/archive/' + case + '/ocn/proc/tseries/year_1'

# %%
# %%time
ds_list = []
print(f'reading {case}')
ds2 = xr.Dataset()

for v in variables:  
    print(v)
    files = sorted(glob(f'{path}/{case}.annual.{v}.????-????.nc'))       
    dsv=xr.open_mfdataset(files, data_vars="minimal", coords='minimal', compat="override", parallel=True, concat_dim="time",
                       drop_variables=["transport_components", "transport_regions"], decode_times=True)
    
    ds2 = xr.merge((ds2, dsv))
    ds_list.append(ds2)
# Out:
# reading g.e22a06.G1850ECOIAF_JRA_PHYS_DEV.TL319_g17.4p4z.zoo4both
# diatC
# coccoC
# spC
# diazC
# zoo1C
# zoo2C
# zoo3C
# zoo4C
# IFRAC
# PD
# Fe
# diatChl
# spChl
# diazChl
# coccoChl
# CPU times: user 3.77 s, sys: 389 ms, total: 4.16 s
# Wall time: 6.34 s

# %% [markdown]
# ### get even longer lived (800 d) zoo4 run

# %%
case = 'g.e22a06.G1850ECOIAF_JRA_PHYS_DEV.TL319_g17.4p4z.zoo4longlived2'
path = '/glade/scratch/kristenk/archive/' + case + '/ocn/proc/tseries/year_1'

# %%
# %%time
ds_list = []
print(f'reading {case}')
ds3 = xr.Dataset()

for v in variables:  
    print(v)
    files = sorted(glob(f'{path}/{case}.annual.{v}.????-????.nc'))       
    dsv=xr.open_mfdataset(files, data_vars="minimal", coords='minimal', compat="override", parallel=True, concat_dim="time",
                       drop_variables=["transport_components", "transport_regions"], decode_times=True)
    
    ds3 = xr.merge((ds3, dsv))
    ds_list.append(ds3)
# Out:
# reading g.e22a06.G1850ECOIAF_JRA_PHYS_DEV.TL319_g17.4p4z.zoo4longlived2
# diatC
# coccoC
# spC
# diazC
# zoo1C
# zoo2C
# zoo3C
# zoo4C
# IFRAC
# PD
# Fe
# diatChl
# spChl
# diazChl
# coccoChl
# CPU times: user 3.76 s, sys: 386 ms, total: 4.15 s
# Wall time: 5.87 s

# %% [markdown]
# ### get even longer lived test1, slow growing

# %%
case = 'g.e22a06.G1850ECOIAF_JRA_PHYS_DEV.TL319_g17.4p4z.zoo4test1'
path = '/glade/scratch/kristenk/archive/' + case + '/ocn/proc/tseries/year_1'

# %%
# %%time
ds_list = []
print(f'reading {case}')
ds4 = xr.Dataset()

for v in variables:  
    print(v)
    files = sorted(glob(f'{path}/{case}.annual.{v}.????-????.nc'))       
    dsv=xr.open_mfdataset(files, data_vars="minimal", coords='minimal', compat="override", parallel=True, concat_dim="time",
                       drop_variables=["transport_components", "transport_regions"], decode_times=True)
    
    ds4 = xr.merge((ds4, dsv))
    ds_list.append(ds4)
# Out:
# reading g.e22a06.G1850ECOIAF_JRA_PHYS_DEV.TL319_g17.4p4z.zoo4test1
# diatC
# coccoC
# spC
# diazC
# zoo1C
# zoo2C
# zoo3C
# zoo4C
# IFRAC
# PD
# Fe
# diatChl
# spChl
# diazChl
# coccoChl
# CPU times: user 2.27 s, sys: 182 ms, total: 2.45 s
# Wall time: 3.53 s

# %%
ds_grid = pop_tools.get_grid('POP_gx1v7')
lons=ds_grid.TLONG
lats=ds_grid.TLAT
area=ds_grid.TAREA
area_m=ds_grid.TAREA * 1e-4

ds['z_t']=ds_grid.z_t
depths_m=ds_grid.z_t * 0.01
dz=ds_grid.dz
dz_m=ds_grid.dz * 0.01
tlen=len(ds.time)
years = np.arange(1999,1999+tlen)

# %%
len(years)
# Out:
# 20

# %%
sigma_surf = ds.PD.isel(z_t=0) * 1000. - 1000.

# %%
sigma_surf.isel(time=0).plot()

# %%
#make time-varying masks for sigma bounds 26 to 27 and >27 in Southern ocean
sigma26to27 = sigma_surf.where(lats<0.).where(sigma_surf > 26.).where(sigma_surf<27.)
sigma_gt27 = sigma_surf.where(lats<0.).where(sigma_surf>27.)

# %%
sigma26to27.isel(time=0).plot()

# %%
sigma_gt27.isel(time=0).plot()

# %%
def adjust_pop_grid(tlon,tlat,field):
    nj = tlon.shape[0]
    ni = tlon.shape[1]
    xL = int(ni/2 - 1)
    xR = int(xL + ni)

    tlon = np.where(np.greater_equal(tlon,min(tlon[:,0])),tlon-360.,tlon)
    lon  = np.concatenate((tlon,tlon+360.),1)
    lon = lon[:,xL:xR]

    if ni == 320:
        lon[367:-3,0] = lon[367:-3,0]+360.
    lon = lon - 360.
    lon = np.hstack((lon,lon[:,0:1]+360.))
    if ni == 320:
        lon[367:,-1] = lon[367:,-1] - 360.

    #-- trick cartopy into doing the right thing:
    #   it gets confused when the cyclic coords are identical
    lon[:,0] = lon[:,0]-1e-8
    
    #-- periodicity
    lat  = np.concatenate((tlat,tlat),1)
    lat = lat[:,xL:xR]
    lat = np.hstack((lat,lat[:,0:1]))

    field = np.ma.concatenate((field,field),1)
    field = field[:,xL:xR]
    field = np.ma.hstack((field,field[:,0:1]))
    return lon,lat,field

# %%
ds['TOT_zooC']=ds.zoo1C + ds.zoo2C + ds.zoo3C + ds.zoo4C
ds2['TOT_zooC']=ds2.zoo1C + ds2.zoo2C + ds2.zoo3C + ds2.zoo4C

# %%
lon, lat, field = adjust_pop_grid(lons, lats, ds.TOT_zooC.isel(time=10,z_t_150m=0))
sh = lat[:, 0] < 0
lon = lon[sh, :]
lat = lat[sh, :]
field = field[sh, :]

# %%
lon, lat, field3 = adjust_pop_grid(lons, lats, ds2.TOT_zooC.isel(time=10,z_t_150m=0))
sh = lat[:, 0] < 0
lon = lon[sh, :]
lat = lat[sh, :]
field3 = field3[sh, :]

# %%
sigma = sigma_surf.isel(time=10)
lon2,lat2,field2 = adjust_pop_grid(lons, lats, sigma)
lons_sh2 = lon2[sh, :]
lats_sh2 = lat2[sh, :]
field2 = field2[sh, :]

# %%
fig = plt.figure(figsize=(6,5))
#----------
ax = fig.add_subplot(1,1,1, projection=ccrs.SouthPolarStereo())
ax.set_title('total zooplankton at surface, 2009')
ax.set_extent([-180, 180, -90, -30], ccrs.PlateCarree())

#################### make it a circle
theta = np.linspace(0, 2*np.pi, 100)
center, radius = [0.5, 0.5], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)

ax.set_boundary(circle, transform=ax.transAxes)
#################### end circle

ax.coastlines('10m',linewidth=0.5)
pc=ax.pcolormesh(lon, lat, 
                 field, vmin=0, vmax=3, 
                 cmap='YlGnBu_r',
                 transform=ccrs.PlateCarree())

pci=ax.contour(lons_sh2, lats_sh2, 
                 field2, 
                 levels=[26,27], 
                 colors='blue',
                 transform=ccrs.PlateCarree())
fmt = {}
strs = ['${\sigma}_{\Theta}$26', '${\sigma}_{\Theta}$27']
for l, s in zip(pci.levels, strs):
    fmt[l] = s
ax.clabel(pci, pci.levels, inline=True, fmt=fmt, fontsize=10)
cbar1 = fig.colorbar(pc, ax=ax,extend='both',label='Zooplankton biomass (mmol m$^{-3}$)')

# %%
fig = plt.figure(figsize=(6,5))
#----------
ax = fig.add_subplot(1,1,1, projection=ccrs.SouthPolarStereo())
#ax.set_title('total zooplankton at surface, 2009')
ax.set_extent([-180, 180, -90, -30], ccrs.PlateCarree())

#################### make it a circle
theta = np.linspace(0, 2*np.pi, 100)
center, radius = [0.5, 0.5], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)

ax.set_boundary(circle, transform=ax.transAxes)
#################### end circle

ax.coastlines('10m',linewidth=0.5)
# pc=ax.pcolormesh(lon, lat, 
#                  field, vmin=0, vmax=3, 
#                  cmap='YlGnBu_r',
#                  transform=ccrs.PlateCarree())

pci=ax.contour(lons_sh2, lats_sh2, 
                 field2, 
                 levels=[26,27], 
                 colors='blue',
                 transform=ccrs.PlateCarree())
fmt = {}
strs = ['${\sigma}_{\Theta}$26', '${\sigma}_{\Theta}$27']
for l, s in zip(pci.levels, strs):
    fmt[l] = s
ax.clabel(pci, pci.levels, inline=True, fmt=fmt, fontsize=10);
#cbar1 = fig.colorbar(pc, ax=ax,extend='both',label='Zooplankton biomass (mmol m$^{-3}$)')

# %%
fig = plt.figure(figsize=(6,5))
#----------
ax = fig.add_subplot(1,1,1, projection=ccrs.SouthPolarStereo())
ax.set_title('total zooplankton at surface, 2009')
ax.set_extent([-180, 180, -90, -30], ccrs.PlateCarree())

#################### make it a circle
theta = np.linspace(0, 2*np.pi, 100)
center, radius = [0.5, 0.5], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)

ax.set_boundary(circle, transform=ax.transAxes)
#################### end circle

ax.coastlines('10m',linewidth=0.5)
pc=ax.pcolormesh(lon, lat, 
                 field3, vmin=0, vmax=2, 
                 cmap='YlGnBu_r',
                 transform=ccrs.PlateCarree())

pci=ax.contour(lons_sh2, lats_sh2, 
                 field2, 
                 levels=[26,27], 
                 colors='blue',
                 transform=ccrs.PlateCarree(), label='25% annual mean ice cover')
fmt = {}
strs = ['${\sigma}_{\Theta}$26', '${\sigma}_{\Theta}$27']
for l, s in zip(pci.levels, strs):
    fmt[l] = s
ax.clabel(pci, pci.levels, inline=True, fmt=fmt, fontsize=10)
cbar1 = fig.colorbar(pc, ax=ax,extend='max',label='Zooplankton biomass (mmol m$^{-3}$)')

# %% [markdown]
# #### make integrated biomass

# %%
tmp = ds.zoo1C * 10.
ds['zoo1C_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds.zoo2C * 10.
ds['zoo2C_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds.zoo3C * 10.
ds['zoo3C_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds.zoo4C * 10.
ds['zoo4C_zint'] = tmp.sum(dim='z_t_150m')

ds['zooC_TOT_zint'] = ds['zoo1C_zint'] + ds['zoo2C_zint'] + ds['zoo3C_zint'] + ds['zoo4C_zint']

tmp = ds.spC * 10.
ds['spC_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds.diatC * 10.
ds['diatC_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds.coccoC * 10.
ds['coccoC_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds.diazC * 10.
ds['diazC_zint'] = tmp.sum(dim='z_t_150m')

ds['phytoC_TOT_zint'] = ds['spC_zint'] + ds['diatC_zint'] + ds['coccoC_zint'] + ds['diazC_zint']

# %%
tmp = ds2.zoo1C * 10.
ds2['zoo1C_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds2.zoo2C * 10.
ds2['zoo2C_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds2.zoo3C * 10.
ds2['zoo3C_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds2.zoo4C * 10.
ds2['zoo4C_zint'] = tmp.sum(dim='z_t_150m')

ds2['zooC_TOT_zint'] = ds2['zoo1C_zint'] + ds2['zoo2C_zint'] + ds2['zoo3C_zint'] + ds2['zoo4C_zint']

tmp = ds2.spC * 10.
ds2['spC_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds2.diatC * 10.
ds2['diatC_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds2.coccoC * 10.
ds2['coccoC_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds2.diazC * 10.
ds2['diazC_zint'] = tmp.sum(dim='z_t_150m')

ds2['phytoC_TOT_zint'] = ds2['spC_zint'] + ds2['diatC_zint'] + ds2['coccoC_zint'] + ds2['diazC_zint']

# %%
tmp = ds3.zoo1C * 10.
ds3['zoo1C_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds3.zoo2C * 10.
ds3['zoo2C_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds3.zoo3C * 10.
ds3['zoo3C_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds3.zoo4C * 10.
ds3['zoo4C_zint'] = tmp.sum(dim='z_t_150m')

ds3['zooC_TOT_zint'] = ds3['zoo1C_zint'] + ds3['zoo2C_zint'] + ds3['zoo3C_zint'] + ds3['zoo4C_zint']

tmp = ds3.spC * 10.
ds3['spC_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds3.diatC * 10.
ds3['diatC_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds3.coccoC * 10.
ds3['coccoC_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds3.diazC * 10.
ds3['diazC_zint'] = tmp.sum(dim='z_t_150m')

ds3['phytoC_TOT_zint'] = ds3['spC_zint'] + ds3['diatC_zint'] + ds3['coccoC_zint'] + ds3['diazC_zint']

# %%
tmp = ds4.zoo1C * 10.
ds4['zoo1C_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds4.zoo2C * 10.
ds4['zoo2C_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds4.zoo3C * 10.
ds4['zoo3C_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds4.zoo4C * 10.
ds4['zoo4C_zint'] = tmp.sum(dim='z_t_150m')

ds4['zooC_TOT_zint'] = ds4['zoo1C_zint'] + ds4['zoo2C_zint'] + ds4['zoo3C_zint'] + ds4['zoo4C_zint']

tmp = ds4.spC * 10.
ds4['spC_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds4.diatC * 10.
ds4['diatC_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds4.coccoC * 10.
ds4['coccoC_zint'] = tmp.sum(dim='z_t_150m')
tmp = ds4.diazC * 10.
ds4['diazC_zint'] = tmp.sum(dim='z_t_150m')

ds4['phytoC_TOT_zint'] = ds4['spC_zint'] + ds4['diatC_zint'] + ds4['coccoC_zint'] + ds4['diazC_zint']

# %%
ds['tot_chl'] = ds['spChl'] + ds['diatChl'] + ds['coccoChl'] + ds['diazChl']
ds2['tot_chl'] = ds2['spChl'] + ds2['diatChl'] + ds2['coccoChl'] + ds2['diazChl']
ds3['tot_chl'] = ds3['spChl'] + ds3['diatChl'] + ds3['coccoChl'] + ds3['diazChl']
ds4['tot_chl'] = ds4['spChl'] + ds4['diatChl'] + ds4['coccoChl'] + ds4['diazChl']

# %% [markdown]
# ### make timeseries of means between sigma-theta 26 an 27

# %%
ts_boxes_26to27 = xr.Dataset({v: ds[v] for v in ['time']})

masked = ds['zoo1C_zint'].where(sigma26to27>0.)
ts_boxes_26to27['zoo1C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['zoo2C_zint'].where(sigma26to27>0.)
ts_boxes_26to27['zoo2C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['zoo3C_zint'].where(sigma26to27>0.)
ts_boxes_26to27['zoo3C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['zoo4C_zint'].where(sigma26to27>0.)
ts_boxes_26to27['zoo4C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['spC_zint'].where(sigma26to27>0.)
ts_boxes_26to27['spC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['diatC_zint'].where(sigma26to27>0.)
ts_boxes_26to27['diatC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['coccoC_zint'].where(sigma26to27>0.)
ts_boxes_26to27['coccoC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['zooC_TOT_zint'].where(sigma26to27>0.)
ts_boxes_26to27['zooC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['phytoC_TOT_zint'].where(sigma26to27>0.)
ts_boxes_26to27['phytoC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['Fe'].isel(z_t=slice(0,15)).mean(dim='z_t').where(sigma26to27>0.)
ts_boxes_26to27['Fe'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['tot_chl'].isel(z_t_150m=0).where(sigma26to27>0.)
ts_boxes_26to27['tot_chl_surf'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()


# tlen=len(ds.time)
# #years = np.arange(1958,1958+tlen)
ts_boxes_26to27['time']=years

# %%
ts2_boxes_26to27 = xr.Dataset({v: ds2[v] for v in ['time']})

masked = ds2['zoo1C_zint'].where(sigma26to27>0.)
ts2_boxes_26to27['zoo1C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['zoo2C_zint'].where(sigma26to27>0.)
ts2_boxes_26to27['zoo2C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['zoo3C_zint'].where(sigma26to27>0.)
ts2_boxes_26to27['zoo3C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['zoo4C_zint'].where(sigma26to27>0.)
ts2_boxes_26to27['zoo4C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['spC_zint'].where(sigma26to27>0.)
ts2_boxes_26to27['spC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['diatC_zint'].where(sigma26to27>0.)
ts2_boxes_26to27['diatC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['coccoC_zint'].where(sigma26to27>0.)
ts2_boxes_26to27['coccoC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['zooC_TOT_zint'].where(sigma26to27>0.)
ts2_boxes_26to27['zooC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['phytoC_TOT_zint'].where(sigma26to27>0.)
ts2_boxes_26to27['phytoC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['Fe'].isel(z_t=slice(0,15)).mean(dim='z_t').where(sigma26to27>0.)
ts2_boxes_26to27['Fe'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['tot_chl'].isel(z_t_150m=0).where(sigma26to27>0.)
ts2_boxes_26to27['tot_chl_surf'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

tlen=len(ds2.time)
#years = np.arange(1958,1958+tlen)
ts2_boxes_26to27['time']=years

# %%
ts3_boxes_26to27 = xr.Dataset({v: ds3[v] for v in ['time']})

masked = ds3['zoo1C_zint'].where(sigma26to27>0.)
ts3_boxes_26to27['zoo1C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['zoo2C_zint'].where(sigma26to27>0.)
ts3_boxes_26to27['zoo2C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['zoo3C_zint'].where(sigma26to27>0.)
ts3_boxes_26to27['zoo3C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['zoo4C_zint'].where(sigma26to27>0.)
ts3_boxes_26to27['zoo4C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['spC_zint'].where(sigma26to27>0.)
ts3_boxes_26to27['spC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['diatC_zint'].where(sigma26to27>0.)
ts3_boxes_26to27['diatC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['coccoC_zint'].where(sigma26to27>0.)
ts3_boxes_26to27['coccoC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['zooC_TOT_zint'].where(sigma26to27>0.)
ts3_boxes_26to27['zooC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['phytoC_TOT_zint'].where(sigma26to27>0.)
ts3_boxes_26to27['phytoC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['Fe'].isel(z_t=slice(0,15)).mean(dim='z_t').where(sigma26to27>0.)
ts3_boxes_26to27['Fe'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['tot_chl'].isel(z_t_150m=0).where(sigma26to27>0.)
ts3_boxes_26to27['tot_chl_surf'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

# tlen=len(ds3.time)
# #years = np.arange(1958,1958+tlen)
ts3_boxes_26to27['time']=years

# %%
# ts4_boxes_26to27 = xr.Dataset({v: ds4[v] for v in ['time']})

# masked = ds4['zoo1C_zint'].where(sigma26to27>0.)
# ts4_boxes_26to27['zoo1C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

# masked = ds4['zoo2C_zint'].where(sigma26to27>0.)
# ts4_boxes_26to27['zoo2C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

# masked = ds4['zoo3C_zint'].where(sigma26to27>0.)
# ts4_boxes_26to27['zoo3C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

# masked = ds4['zoo4C_zint'].where(sigma26to27>0.)
# ts4_boxes_26to27['zoo4C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

# masked = ds4['spC_zint'].where(sigma26to27>0.)
# ts4_boxes_26to27['spC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

# masked = ds4['diatC_zint'].where(sigma26to27>0.)
# ts4_boxes_26to27['diatC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

# masked = ds4['coccoC_zint'].where(sigma26to27>0.)
# ts4_boxes_26to27['coccoC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

# masked = ds4['zooC_TOT_zint'].where(sigma26to27>0.)
# ts4_boxes_26to27['zooC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

# masked = ds4['phytoC_TOT_zint'].where(sigma26to27>0.)
# ts4_boxes_26to27['phytoC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

# masked = ds4['Fe'].isel(z_t=slice(0,15)).mean(dim='z_t').where(sigma26to27>0.)
# ts4_boxes_26to27['Fe'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

# masked = ds4['tot_chl'].isel(z_t_150m=0).where(sigma26to27>0.)
# ts4_boxes_26to27['tot_chl_surf'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

# # tlen=len(ds3.time)
# # #years = np.arange(1958,1958+tlen)
# ts4_boxes_26to27['time']=np.arange(1999,1999+10) #years

# %% [markdown]
# ### Make means of integrated biomass pools

# %%
ds_SAZ_means = xr. Dataset()
ds_SAZ_means2 = xr. Dataset()
ds_SAZ_means3 = xr.Dataset()
#ds_SAZ_means4 = xr.Dataset()

# %%
mean_zoo = ts_boxes_26to27['zooC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mean_zoo2 = ts2_boxes_26to27['zooC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mean_zoo3 = ts3_boxes_26to27['zooC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')
#mean_zoo4 = ts4_boxes_26to27['zooC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_SAZ_means['mean_tot_zoo'] = mean_zoo
ds_SAZ_means2['mean_tot_zoo'] = mean_zoo2
ds_SAZ_means3['mean_tot_zoo'] = mean_zoo3
#ds_SAZ_means4['mean_tot_zoo'] = mean_zoo4

# %%
mean_phyto = ts_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mean_phyto2 = ts2_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mean_phyto3 = ts3_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')
#mean_phyto4 = ts4_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_SAZ_means['mean_tot_phyto'] = mean_phyto
ds_SAZ_means2['mean_tot_phyto'] = mean_phyto2
ds_SAZ_means3['mean_tot_phyto'] = mean_phyto3
#ds_SAZ_means4['mean_tot_phyto'] = mean_phyto4

# %%
microzoo_mean = (ts_boxes_26to27['zoo1C_zint'].isel(time=slice(2,20))+ts_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))).mean(dim='time')
microzoo_mean2 = (ts2_boxes_26to27['zoo1C_zint'].isel(time=slice(2,20))+ts2_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))).mean(dim='time')
microzoo_mean3 = (ts3_boxes_26to27['zoo1C_zint'].isel(time=slice(2,20))+ts3_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))).mean(dim='time')
#microzoo_mean4 = (ts4_boxes_26to27['zoo1C_zint'].isel(time=slice(2,20))+ts4_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))).mean(dim='time')

ds_SAZ_means['mean_microzoo'] = microzoo_mean
ds_SAZ_means2['mean_microzoo'] = microzoo_mean2
ds_SAZ_means3['mean_microzoo'] = microzoo_mean3
#ds_SAZ_means4['mean_microzoo'] = microzoo_mean4

# %%
sp_mean = ts_boxes_26to27['spC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
sp_mean2 = ts2_boxes_26to27['spC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
sp_mean3 = ts3_boxes_26to27['spC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
#sp_mean4 = ts4_boxes_26to27['spC_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_SAZ_means['mean_sp'] = sp_mean
ds_SAZ_means2['mean_sp'] = sp_mean2
ds_SAZ_means3['mean_sp'] = sp_mean3
#ds_SAZ_means4['mean_sp'] = sp_mean4

# %%
cocco_mean = ts_boxes_26to27['coccoC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
cocco_mean2 = ts2_boxes_26to27['coccoC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
cocco_mean3 = ts3_boxes_26to27['coccoC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
#cocco_mean4 = ts4_boxes_26to27['coccoC_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_SAZ_means['mean_cocco'] = cocco_mean
ds_SAZ_means2['mean_cocco'] = cocco_mean2
ds_SAZ_means3['mean_cocco'] = cocco_mean3
#ds_SAZ_means4['mean_cocco'] = cocco_mean4

# %%
diat_mean = ts_boxes_26to27['diatC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
diat_mean2 = ts2_boxes_26to27['diatC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
diat_mean3 = ts3_boxes_26to27['diatC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
#diat_mean4 = ts4_boxes_26to27['diatC_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_SAZ_means['mean_diat'] = diat_mean
ds_SAZ_means2['mean_diat'] = diat_mean2
ds_SAZ_means3['mean_diat'] = diat_mean3
#ds_SAZ_means4['mean_diat'] = diat_mean4

# %%
mesozoo_mean=ts_boxes_26to27['zoo3C_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mesozoo_mean2=ts2_boxes_26to27['zoo3C_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mesozoo_mean3=ts3_boxes_26to27['zoo3C_zint'].isel(time=slice(2,tlen)).mean(dim='time')
#mesozoo_mean4=ts4_boxes_26to27['zoo3C_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_SAZ_means['mean_mesozoo'] = mesozoo_mean
ds_SAZ_means2['mean_mesozoo'] = mesozoo_mean2
ds_SAZ_means3['mean_mesozoo'] = mesozoo_mean3
#ds_SAZ_means4['mean_mesozoo'] = mesozoo_mean4

# %%
macrozoo_mean = ts_boxes_26to27['zoo4C_zint'].isel(time=slice(2,tlen)).mean(dim='time')
macrozoo_mean2 = ts2_boxes_26to27['zoo4C_zint'].isel(time=slice(2,tlen)).mean(dim='time')
macrozoo_mean3 = ts3_boxes_26to27['zoo4C_zint'].isel(time=slice(2,tlen)).mean(dim='time')
#macrozoo_mean4 = ts4_boxes_26to27['zoo4C_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_SAZ_means['mean_macrozoo'] = macrozoo_mean
ds_SAZ_means2['mean_macrozoo'] = macrozoo_mean2
ds_SAZ_means3['mean_macrozoo'] = macrozoo_mean3
#ds_SAZ_means4['mean_macrozoo'] = macrozoo_mean4

# %%
# set width of bar 
barWidth = 0.2
fig = plt.subplots(figsize =(12, 8)) 
   
# set height of bar 
#phytoC, zooC, microzooC, mesozooC, macrozooC
high_mort = [ds_SAZ_means.mean_tot_phyto.values, ds_SAZ_means.mean_tot_zoo.values,ds_SAZ_means.mean_microzoo.values, ds_SAZ_means.mean_mesozoo.values, ds_SAZ_means.mean_macrozoo.values] 
low_mort = [ds_SAZ_means2.mean_tot_phyto.values, ds_SAZ_means2.mean_tot_zoo.values,ds_SAZ_means2.mean_microzoo.values, ds_SAZ_means2.mean_mesozoo.values, ds_SAZ_means2.mean_macrozoo.values] 
lower_mort = [ds_SAZ_means3.mean_tot_phyto.values, ds_SAZ_means3.mean_tot_zoo.values,ds_SAZ_means3.mean_microzoo.values, ds_SAZ_means3.mean_mesozoo.values, ds_SAZ_means3.mean_macrozoo.values]
#lowLin_highQuad = [ds_SAZ_means4.mean_tot_phyto.values, ds_SAZ_means4.mean_tot_zoo.values,ds_SAZ_means4.mean_microzoo.values, ds_SAZ_means4.mean_mesozoo.values, ds_SAZ_means4.mean_macrozoo.values]
   
# Set position of bar on X axis 
br1 = np.arange(len(high_mort)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 
#br4 = [x + barWidth for x in br3] 
# Make the plot 
plt.bar(br1, high_mort, color ='r', width = barWidth, 
        edgecolor ='grey', label ='high_mort') 
plt.bar(br2, low_mort, color ='g', width = barWidth, 
        edgecolor ='grey', label ='low_mort') 
plt.bar(br3, lower_mort, color ='b', width = barWidth, 
        edgecolor ='grey', label ='lower_mort') 
#plt.bar(br4, lowLin_highQuad, color ='purple', width = barWidth, 
#        edgecolor ='grey', label ='lowLin_highQuad') 
    
# Adding Xticks  
#plt.xlabel('', fontweight ='bold') 
plt.ylabel('integrated biomass in SAZ', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(high_mort))], 
           ['tot_phytoC', 'tot_zooC', 'microzooC', 'mesozooC', 'macrozooC']) 
plt.legend()

# %%
style.use('ggplot')
fig, ax = plt.subplots(nrows=2,ncols=1,figsize=(10,7))
fig.suptitle('Southern Ocean, ${\sigma}_{\Theta}$ 26 to 27 surface outcrop, integrated mean biomass')
ax[0].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[0].plot(ts_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         ts_boxes_26to27['zooC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means.mean_tot_zoo, 
         color='red', label='zooplankton')

ax[0].plot(ts2_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         ts2_boxes_26to27['zooC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means2.mean_tot_zoo, 
         color='green', label='zooplankton2')

ax[0].plot(ts3_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         ts3_boxes_26to27['zooC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means3.mean_tot_zoo, 
         color='blue', label='zooplankton3')

# ax[0].plot(ts4_boxes_26to27['time'].isel(time=slice(2,tlen)), 
#          ts4_boxes_26to27['zooC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means4.mean_tot_zoo, 
#          color='blue', label='zooplankton4')

ax[0].legend()

ax[1].plot(ts_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means.mean_tot_phyto, 
           color='green', label='phytoplankton')
ax[1].plot(ts2_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         ts2_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means2.mean_tot_phyto, 
         color='turquoise', label='phytoplankton2')
ax[1].plot(ts3_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         ts3_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means3.mean_tot_phyto, 
         color='orange', label='phytoplankton3')

# ax[1].plot(ts4_boxes_26to27['time'].isel(time=slice(2,tlen)), 
#          ts4_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means4.mean_tot_phyto, 
#          color='red', label='phytoplankton4')

ax[1].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[1].set_xlabel('Year')
ax[1].legend();

# %%
style.use('ggplot')
fig, ax = plt.subplots(nrows=4,ncols=1,figsize=(10,7))
fig.suptitle('Southern Ocean, ${\sigma}_{\Theta}$ 26 to 27 surface outcrop, integrated mean biomass')
ax[0].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[0].plot(ts_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         (ts_boxes_26to27['zoo1C_zint'].isel(time=slice(2,tlen))+ts_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))) - ds_SAZ_means['mean_microzoo'], 
         color='red', label='microzooplankton (zoo1 + zoo2)')

ax[0].plot(ts2_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         (ts2_boxes_26to27['zoo1C_zint'].isel(time=slice(2,tlen))+ts2_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))) - ds_SAZ_means2['mean_microzoo'], 
         color='blue', label='microzooplankton2 (zoo1 + zoo2)')

ax[0].plot(ts3_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         (ts3_boxes_26to27['zoo1C_zint'].isel(time=slice(2,tlen))+ts3_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))) - ds_SAZ_means3['mean_microzoo'], 
         color='orange', label='microzooplankton3 (zoo1 + zoo2)')

# ax[0].plot(ts4_boxes_26to27['time'].isel(time=slice(2,tlen)), 
#          (ts4_boxes_26to27['zoo1C_zint'].isel(time=slice(2,tlen))+ts4_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))) - ds_SAZ_means4['mean_microzoo'], 
#          color='purple', label='microzooplankton4 (zoo1 + zoo2)')


ax[0].legend()

ax[1].plot(ts_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts_boxes_26to27['spC_zint'].isel(time=slice(2,tlen))- ds_SAZ_means['mean_sp'], 
           color='green', label='sp')

ax[1].plot(ts2_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts2_boxes_26to27['spC_zint'].isel(time=slice(2,tlen))- ds_SAZ_means2['mean_sp'], 
           color='orange', label='sp2')

ax[1].plot(ts3_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts3_boxes_26to27['spC_zint'].isel(time=slice(2,tlen))- ds_SAZ_means3['mean_sp'], 
           color='red', label='sp3')

# ax[1].plot(ts4_boxes_26to27['time'].isel(time=slice(2,tlen)), 
#            ts4_boxes_26to27['spC_zint'].isel(time=slice(2,tlen))- ds_SAZ_means4['mean_sp'], 
#            color='purple', label='sp4')

ax[1].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[1].set_xlabel('Year')
ax[1].legend()

ax[2].plot(ts_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts_boxes_26to27['coccoC_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means['mean_cocco'], 
           color='turquoise', label='cocco')
ax[2].plot(ts2_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts2_boxes_26to27['coccoC_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means2['mean_cocco'], 
           color='royalblue', label='cocco2')
ax[2].plot(ts3_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts3_boxes_26to27['coccoC_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means3['mean_cocco'], 
           color='lightblue', label='cocco3')
# ax[2].plot(ts4_boxes_26to27['time'].isel(time=slice(2,tlen)), 
#            ts4_boxes_26to27['coccoC_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means4['mean_cocco'], 
#            color='blue', label='cocco4')

ax[2].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[2].set_xlabel('Year')
ax[2].legend()



ax[3].plot(ts_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts_boxes_26to27['diatC_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means['mean_diat'], 
           color='purple', label='diat')
ax[3].plot(ts2_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts2_boxes_26to27['diatC_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means2['mean_diat'], 
           color='magenta', label='diat2')
ax[3].plot(ts3_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts3_boxes_26to27['diatC_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means3['mean_diat'], 
           color='darkgreen', label='diat3')
# ax[3].plot(ts4_boxes_26to27['time'].isel(time=slice(2,tlen)), 
#            ts4_boxes_26to27['diatC_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means4['mean_diat'], 
#            color='green', label='diat4')

ax[3].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[3].set_xlabel('Year')
ax[3].legend();

# %%
style.use('ggplot')
fig, ax = plt.subplots(nrows=3,ncols=1,figsize=(10,7))
fig.suptitle('Southern Ocean, ${\sigma}_{\Theta}$ 26 to 27 surface outcrop, integrated mean biomass')
ax[0].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[0].plot(ts_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         ts_boxes_26to27['zoo3C_zint'].isel(time=slice(2,tlen))- ds_SAZ_means['mean_mesozoo'], 
         color='red', label='mesozooplankton')
ax[0].plot(ts2_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         ts2_boxes_26to27['zoo3C_zint'].isel(time=slice(2,tlen))- ds_SAZ_means2['mean_mesozoo'], 
         color='pink', label='mesozooplankton2')
ax[0].plot(ts3_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         ts3_boxes_26to27['zoo3C_zint'].isel(time=slice(2,tlen))- ds_SAZ_means3['mean_mesozoo'], 
         color='magenta', label='mesozooplankton3')
# ax[0].plot(ts4_boxes_26to27['time'].isel(time=slice(2,tlen)), 
#          ts4_boxes_26to27['zoo3C_zint'].isel(time=slice(2,tlen))- ds_SAZ_means4['mean_mesozoo'], 
#          color='orange', label='mesozooplankton4')

ax[0].legend()

ax[1].plot(ts_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means['mean_tot_phyto'], 
           color='green', label='total phytoplankton')

ax[1].plot(ts2_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts2_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means2['mean_tot_phyto'], 
           color='lightgreen', label='total phytoplankton2')
ax[1].plot(ts3_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts3_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means3['mean_tot_phyto'], 
           color='turquoise', label='total phytoplankton3')
# ax[1].plot(ts4_boxes_26to27['time'].isel(time=slice(2,tlen)), 
#            ts4_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means4['mean_tot_phyto'], 
#            color='orange', label='total phytoplankton4')

ax[1].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[1].set_xlabel('Year')
ax[1].legend()

ax[2].plot(ts_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts_boxes_26to27['Fe'].isel(time=slice(2,tlen)), 
           color='orange', label='mean top 150m Fe')
ax[2].plot(ts2_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts2_boxes_26to27['Fe'].isel(time=slice(2,tlen)), 
           color='chocolate', label='mean top 150m Fe2')
ax[2].plot(ts3_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts3_boxes_26to27['Fe'].isel(time=slice(2,tlen)), 
           color='green', label='mean top 150m Fe3')
# ax[2].plot(ts4_boxes_26to27['time'].isel(time=slice(2,tlen)), 
#            ts4_boxes_26to27['Fe'].isel(time=slice(2,tlen)), 
#            color='green', label='mean top 150m Fe4')

ax[2].set_ylabel('Fe (mmol m$^{-3}$)')
ax[2].set_xlabel('Year')
ax[2].legend();

# %%
style.use('ggplot')
fig, ax = plt.subplots(nrows=4,ncols=1,figsize=(10,10))
fig.suptitle('Southern Ocean, ${\sigma}_{\Theta}$ 26 to 27 surface outcrop, integrated mean biomass')
ax[0].set_ylabel('Biomass (mmol m$^{-2}$)')
years=ts3_boxes_26to27['time'].isel(time=slice(2,tlen))
ax[0].plot(ts_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         ts_boxes_26to27['zoo4C_zint'].isel(time=slice(2,tlen))- ds_SAZ_means['mean_macrozoo'], 
         color='red', label='high zoo4 mort')
ax[0].plot(ts2_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         ts2_boxes_26to27['zoo4C_zint'].isel(time=slice(2,tlen))- ds_SAZ_means2['mean_macrozoo'], 
         color='green', label='lower zoo4 mort')
ax[0].plot(ts3_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         ts3_boxes_26to27['zoo4C_zint'].isel(time=slice(2,tlen))- ds_SAZ_means3['mean_macrozoo'], 
         color='blue', label='lowest zoo4 mort')
ax[0].set_xticks(years)
# ax[0].plot(ts4_boxes_26to27['time'].isel(time=slice(2,tlen)), 
#          ts4_boxes_26to27['zoo4C_zint'].isel(time=slice(2,tlen))- ds_SAZ_means4['mean_macrozoo'], 
#          color='orange', label='lowlin,highquad zoo4 mort')
ax[0].text(0.02, 0.95, 'Macrozooplankton', transform=ax[0].transAxes,fontsize=12, fontweight='bold', va='top')
ax[0].legend()

ax[1].plot(ts_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts_boxes_26to27['zoo3C_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means['mean_mesozoo'], 
           color='orange', label='high zoo4 mort')
ax[1].plot(ts2_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts2_boxes_26to27['zoo3C_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means2['mean_mesozoo'], 
           color='gold', label='lower zoo4 mort')
ax[1].plot(ts3_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts3_boxes_26to27['zoo3C_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means3['mean_mesozoo'], 
           color='red', label='lowest zoo4 mort')
# ax[1].plot(ts4_boxes_26to27['time'].isel(time=slice(2,tlen)), 
#            ts4_boxes_26to27['zoo3C_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means4['mean_mesozoo'], 
#            color='pink', label='lowlin,highquad zoo4 mort')
ax[1].legend()
ax[1].set_xticks(years)
ax[1].text(0.02, 0.5, 'Mesozooplankton', transform=ax[1].transAxes,fontsize=12, fontweight='bold', va='top')
#ax[1].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[1].set_xlabel('Year')



ax[2].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[2].plot(ts_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         (ts_boxes_26to27['zoo1C_zint'].isel(time=slice(2,tlen))+ts_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))) - ds_SAZ_means['mean_microzoo'], 
         color='magenta', label='high zoo4 mort')
ax[2].plot(ts2_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         (ts2_boxes_26to27['zoo1C_zint'].isel(time=slice(2,tlen))+ts2_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))) - ds_SAZ_means2['mean_microzoo'], 
         color='purple', label='lower zoo4 mort')
ax[2].plot(ts3_boxes_26to27['time'].isel(time=slice(2,tlen)), 
         (ts3_boxes_26to27['zoo1C_zint'].isel(time=slice(2,tlen))+ts3_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))) - ds_SAZ_means3['mean_microzoo'], 
         color='orange', label='lowest zoo4 mort')
# ax[2].plot(ts4_boxes_26to27['time'].isel(time=slice(2,tlen)), 
#          (ts4_boxes_26to27['zoo1C_zint'].isel(time=slice(2,tlen))+ts4_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))) - ds_SAZ_means4['mean_microzoo'], 
#          color='red', label='lowlin,highquad zoo4 mort')
ax[2].text(0.02, 0.95, 'Microzooplankton', transform=ax[2].transAxes,fontsize=12, fontweight='bold', va='top')
ax[2].set_xticks(years)
ax[2].legend()


ax[3].plot(ts_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means['mean_tot_phyto'], 
           color='green', label='high zoo4 mort')
ax[3].plot(ts2_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts2_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means2['mean_tot_phyto'], 
           color='lightgreen', label='lower zoo4 mort')
ax[3].plot(ts3_boxes_26to27['time'].isel(time=slice(2,tlen)), 
           ts3_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means3['mean_tot_phyto'], 
           color='turquoise', label='lowest zoo4 mort')
# ax[3].plot(ts4_boxes_26to27['time'].isel(time=slice(2,tlen)), 
#            ts4_boxes_26to27['phytoC_TOT_zint'].isel(time=slice(2,tlen)) - ds_SAZ_means4['mean_tot_phyto'], 
#            color='red', label='lowlin,highquad zoo4 mort')
ax[3].set_xticks(years)
ax[3].text(0.02, 0.95, 'Phytoplankton', transform=ax[3].transAxes,fontsize=12, fontweight='bold', va='top')
ax[3].set_xlabel('Year')
ax[3].legend(loc='lower_right');

# %% [markdown]
# ### make timeseries of means for sigma-theta >27

# %%
ts_boxes_gt27 = xr.Dataset({v: ds[v] for v in ['time']})

masked = ds['zoo1C_zint'].where(sigma_gt27>0.)
ts_boxes_gt27['zoo1C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['zoo2C_zint'].where(sigma_gt27>0.)
ts_boxes_gt27['zoo2C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['zoo3C_zint'].where(sigma_gt27>0.)
ts_boxes_gt27['zoo3C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['zoo4C_zint'].where(sigma_gt27>0.)
ts_boxes_gt27['zoo4C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['spC_zint'].where(sigma_gt27>0.)
ts_boxes_gt27['spC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['diatC_zint'].where(sigma_gt27>0.)
ts_boxes_gt27['diatC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['coccoC_zint'].where(sigma_gt27>0.)
ts_boxes_gt27['coccoC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['zooC_TOT_zint'].where(sigma_gt27>0.)
ts_boxes_gt27['zooC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['phytoC_TOT_zint'].where(sigma_gt27>0.)
ts_boxes_gt27['phytoC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['Fe'].isel(z_t=slice(0,15)).mean(dim='z_t').where(sigma_gt27>0.)
ts_boxes_gt27['Fe'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds['tot_chl'].isel(z_t_150m=0).where(sigma_gt27>0.)
ts_boxes_gt27['tot_chl_surf'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

#tlen=len(ds.time)
years = np.arange(1999,1999+tlen)
ts_boxes_gt27['time']=years

# %%
ts2_boxes_gt27 = xr.Dataset({v: ds2[v] for v in ['time']})

masked = ds2['zoo1C_zint'].where(sigma_gt27>0.)
ts2_boxes_gt27['zoo1C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['zoo2C_zint'].where(sigma_gt27>0.)
ts2_boxes_gt27['zoo2C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['zoo3C_zint'].where(sigma_gt27>0.)
ts2_boxes_gt27['zoo3C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['zoo4C_zint'].where(sigma_gt27>0.)
ts2_boxes_gt27['zoo4C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['spC_zint'].where(sigma_gt27>0.)
ts2_boxes_gt27['spC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['diatC_zint'].where(sigma_gt27>0.)
ts2_boxes_gt27['diatC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['coccoC_zint'].where(sigma_gt27>0.)
ts2_boxes_gt27['coccoC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['zooC_TOT_zint'].where(sigma_gt27>0.)
ts2_boxes_gt27['zooC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['phytoC_TOT_zint'].where(sigma_gt27>0.)
ts2_boxes_gt27['phytoC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['Fe'].isel(z_t=slice(0,15)).mean(dim='z_t').where(sigma_gt27>0.)
ts2_boxes_gt27['Fe'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds2['tot_chl'].isel(z_t_150m=0).where(sigma_gt27>0.)
ts2_boxes_gt27['tot_chl_surf'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

#tlen=len(ds2.time)
#years = np.arange(1958,1958+tlen)
ts2_boxes_gt27['time']=years

# %%
ts3_boxes_gt27 = xr.Dataset({v: ds3[v] for v in ['time']})

masked = ds3['zoo1C_zint'].where(sigma_gt27>0.)
ts3_boxes_gt27['zoo1C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['zoo2C_zint'].where(sigma_gt27>0.)
ts3_boxes_gt27['zoo2C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['zoo3C_zint'].where(sigma_gt27>0.)
ts3_boxes_gt27['zoo3C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['zoo4C_zint'].where(sigma_gt27>0.)
ts3_boxes_gt27['zoo4C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['spC_zint'].where(sigma_gt27>0.)
ts3_boxes_gt27['spC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['diatC_zint'].where(sigma_gt27>0.)
ts3_boxes_gt27['diatC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['coccoC_zint'].where(sigma_gt27>0.)
ts3_boxes_gt27['coccoC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['zooC_TOT_zint'].where(sigma_gt27>0.)
ts3_boxes_gt27['zooC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['phytoC_TOT_zint'].where(sigma_gt27>0.)
ts3_boxes_gt27['phytoC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['Fe'].isel(z_t=slice(0,15)).mean(dim='z_t').where(sigma_gt27>0.)
ts3_boxes_gt27['Fe'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds3['tot_chl'].isel(z_t_150m=0).where(sigma_gt27>0.)
ts3_boxes_gt27['tot_chl_surf'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

#tlen=len(ds2.time)
#years = np.arange(1958,1958+tlen)
ts3_boxes_gt27['time']=years

# %%
ts4_boxes_gt27 = xr.Dataset({v: ds4[v] for v in ['time']})

masked = ds4['zoo1C_zint'].where(sigma_gt27>0.)
ts4_boxes_gt27['zoo1C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds4['zoo2C_zint'].where(sigma_gt27>0.)
ts4_boxes_gt27['zoo2C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds4['zoo3C_zint'].where(sigma_gt27>0.)
ts4_boxes_gt27['zoo3C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds4['zoo4C_zint'].where(sigma_gt27>0.)
ts4_boxes_gt27['zoo4C_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds4['spC_zint'].where(sigma_gt27>0.)
ts4_boxes_gt27['spC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds4['diatC_zint'].where(sigma_gt27>0.)
ts4_boxes_gt27['diatC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds4['coccoC_zint'].where(sigma_gt27>0.)
ts4_boxes_gt27['coccoC_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds4['zooC_TOT_zint'].where(sigma_gt27>0.)
ts4_boxes_gt27['zooC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds4['phytoC_TOT_zint'].where(sigma_gt27>0.)
ts4_boxes_gt27['phytoC_TOT_zint'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds4['Fe'].isel(z_t=slice(0,15)).mean(dim='z_t').where(sigma_gt27>0.)
ts4_boxes_gt27['Fe'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

masked = ds4['tot_chl'].isel(z_t_150m=0).where(sigma_gt27>0.)
ts4_boxes_gt27['tot_chl_surf'] = esmlab.weighted_mean(masked, weights=area_m, dim=['nlat', 'nlon']).compute()

#tlen=len(ds2.time)
#years = np.arange(1958,1958+tlen)
ts4_boxes_gt27['time']=np.arange(1999,1999+10) #years

# %% [markdown]
# ### Make means for AZ

# %%
ds_AZ_means = xr. Dataset()
ds_AZ_means2 = xr. Dataset()
ds_AZ_means3 = xr. Dataset()
ds_AZ_means4 = xr. Dataset()

# %%
mean_zoo = ts_boxes_gt27['zooC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mean_zoo2 = ts2_boxes_gt27['zooC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mean_zoo3 = ts3_boxes_gt27['zooC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mean_zoo4 = ts4_boxes_gt27['zooC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_AZ_means['mean_tot_zoo'] = mean_zoo
ds_AZ_means2['mean_tot_zoo'] = mean_zoo2
ds_AZ_means3['mean_tot_zoo'] = mean_zoo3
ds_AZ_means4['mean_tot_zoo'] = mean_zoo4

# %%
mean_phyto = ts_boxes_gt27['phytoC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mean_phyto2 = ts2_boxes_gt27['phytoC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mean_phyto3 = ts3_boxes_gt27['phytoC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mean_phyto4 = ts4_boxes_gt27['phytoC_TOT_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_AZ_means['mean_tot_phyto'] = mean_phyto
ds_AZ_means2['mean_tot_phyto'] = mean_phyto2
ds_AZ_means3['mean_tot_phyto'] = mean_phyto3
ds_AZ_means4['mean_tot_phyto'] = mean_phyto4

# %%
microzoo_mean = (ts_boxes_gt27['zoo1C_zint'].isel(time=slice(2,20))+ts_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))).mean(dim='time')
microzoo_mean2 = (ts2_boxes_gt27['zoo1C_zint'].isel(time=slice(2,20))+ts2_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))).mean(dim='time')
microzoo_mean3 = (ts3_boxes_gt27['zoo1C_zint'].isel(time=slice(2,20))+ts3_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))).mean(dim='time')
microzoo_mean4 = (ts4_boxes_gt27['zoo1C_zint'].isel(time=slice(2,20))+ts4_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))).mean(dim='time')

ds_AZ_means['mean_microzoo'] = microzoo_mean
ds_AZ_means2['mean_microzoo'] = microzoo_mean2
ds_AZ_means3['mean_microzoo'] = microzoo_mean3
ds_AZ_means4['mean_microzoo'] = microzoo_mean4

# %%
sp_mean = ts_boxes_gt27['spC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
sp_mean2 = ts2_boxes_gt27['spC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
sp_mean3 = ts3_boxes_gt27['spC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
sp_mean4 = ts4_boxes_gt27['spC_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_AZ_means['mean_sp'] = sp_mean
ds_AZ_means2['mean_sp'] = sp_mean2
ds_AZ_means3['mean_sp'] = sp_mean3
ds_AZ_means4['mean_sp'] = sp_mean4

# %%
cocco_mean = ts_boxes_gt27['coccoC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
cocco_mean2 = ts2_boxes_gt27['coccoC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
cocco_mean3 = ts3_boxes_gt27['coccoC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
cocco_mean4 = ts4_boxes_gt27['coccoC_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_AZ_means['mean_cocco'] = cocco_mean
ds_AZ_means2['mean_cocco'] = cocco_mean2
ds_AZ_means3['mean_cocco'] = cocco_mean3
ds_AZ_means4['mean_cocco'] = cocco_mean4

# %%
diat_mean = ts_boxes_gt27['diatC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
diat_mean2 = ts2_boxes_gt27['diatC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
diat_mean3 = ts3_boxes_gt27['diatC_zint'].isel(time=slice(2,tlen)).mean(dim='time')
diat_mean4 = ts4_boxes_gt27['diatC_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_AZ_means['mean_diat'] = diat_mean
ds_AZ_means2['mean_diat'] = diat_mean2
ds_AZ_means3['mean_diat'] = diat_mean3
ds_AZ_means4['mean_diat'] = diat_mean4

# %%
mesozoo_mean=ts_boxes_gt27['zoo3C_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mesozoo_mean2=ts2_boxes_gt27['zoo3C_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mesozoo_mean3=ts3_boxes_gt27['zoo3C_zint'].isel(time=slice(2,tlen)).mean(dim='time')
mesozoo_mean4=ts4_boxes_gt27['zoo3C_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_AZ_means['mean_mesozoo'] = mesozoo_mean
ds_AZ_means2['mean_mesozoo'] = mesozoo_mean2
ds_AZ_means3['mean_mesozoo'] = mesozoo_mean3
ds_AZ_means4['mean_mesozoo'] = mesozoo_mean4

# %%
macrozoo_mean=ts_boxes_gt27['zoo4C_zint'].isel(time=slice(2,tlen)).mean(dim='time')
macrozoo_mean2=ts2_boxes_gt27['zoo4C_zint'].isel(time=slice(2,tlen)).mean(dim='time')
macrozoo_mean3=ts3_boxes_gt27['zoo4C_zint'].isel(time=slice(2,tlen)).mean(dim='time')
macrozoo_mean4=ts4_boxes_gt27['zoo4C_zint'].isel(time=slice(2,tlen)).mean(dim='time')

ds_AZ_means['mean_macrozoo'] = macrozoo_mean
ds_AZ_means2['mean_macrozoo'] = macrozoo_mean2
ds_AZ_means3['mean_macrozoo'] = macrozoo_mean3
ds_AZ_means4['mean_macrozoo'] = macrozoo_mean4

# %%
# set width of bar 
barWidth = 0.2
fig = plt.subplots(figsize =(12, 8)) 
   
# set height of bar 
#phytoC, zooC, microzooC, mesozooC, macrozooC
high_mort = [ds_AZ_means.mean_tot_phyto.values, ds_AZ_means.mean_tot_zoo.values,ds_AZ_means.mean_microzoo.values, ds_AZ_means.mean_mesozoo.values, ds_AZ_means.mean_macrozoo.values] 
low_mort = [ds_AZ_means2.mean_tot_phyto.values, ds_AZ_means2.mean_tot_zoo.values,ds_AZ_means2.mean_microzoo.values, ds_AZ_means2.mean_mesozoo.values, ds_AZ_means2.mean_macrozoo.values] 
lower_mort =[ds_AZ_means3.mean_tot_phyto.values, ds_AZ_means3.mean_tot_zoo.values,ds_AZ_means3.mean_microzoo.values, ds_AZ_means3.mean_mesozoo.values, ds_AZ_means3.mean_macrozoo.values]
#lowLin_highQuad =[ds_AZ_means4.mean_tot_phyto.values, ds_AZ_means4.mean_tot_zoo.values,ds_AZ_means4.mean_microzoo.values, ds_AZ_means4.mean_mesozoo.values, ds_AZ_means4.mean_macrozoo.values]
# Set position of bar on X axis 
br1 = np.arange(len(high_mort)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 
#br4 = [x + barWidth for x in br3]   

# Make the plot 
plt.bar(br1, high_mort, color ='r', width = barWidth, 
        edgecolor ='grey', label ='high_mort') 
plt.bar(br2, low_mort, color ='g', width = barWidth, 
        edgecolor ='grey', label ='low_mort') 
plt.bar(br3, lower_mort, color ='b', width = barWidth, 
        edgecolor ='grey', label ='lower_mort') 
# plt.bar(br4, lowLin_highQuad, color ='purple', width = barWidth, 
#         edgecolor ='grey', label ='lowLin_highQuad') 
      
# Adding Xticks  
#plt.xlabel('', fontweight ='bold') 
plt.ylabel('integrated biomass in AZ', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(high_mort))], 
           ['tot_phytoC', 'tot_zooC', 'microzooC', 'mesozooC', 'macrozooC']) 
plt.legend()

# %%
style.use('ggplot')
fig, ax = plt.subplots(nrows=3,ncols=1,figsize=(10,7))
fig.suptitle('Southern Ocean, ${\sigma}_{\Theta}$ > 27 surface outcrop, integrated mean biomass')
ax[0].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[0].plot(ts_boxes_gt27['time'].isel(time=slice(2,tlen)), 
         ts_boxes_gt27['zoo4C_zint'].isel(time=slice(2,tlen))-ds_AZ_means['mean_macrozoo'], 
         color='red', label='macrozooplankton')
ax[0].plot(ts2_boxes_gt27['time'].isel(time=slice(2,tlen)), 
         ts2_boxes_gt27['zoo4C_zint'].isel(time=slice(2,tlen))-ds_AZ_means2['mean_macrozoo'], 
         color='magenta', label='macrozooplankton2')
ax[0].plot(ts3_boxes_gt27['time'].isel(time=slice(2,tlen)), 
         ts3_boxes_gt27['zoo4C_zint'].isel(time=slice(2,tlen))-ds_AZ_means3['mean_macrozoo'], 
         color='orange', label='macrozooplankton3')
ax[0].plot(ts4_boxes_gt27['time'].isel(time=slice(2,tlen)), 
         ts4_boxes_gt27['zoo4C_zint'].isel(time=slice(2,tlen))-ds_AZ_means4['mean_macrozoo'], 
         color='blue', label='macrozooplankton4')

ax[0].text(0.02, 0.95, 'Macrozooplankton', transform=ax[0].transAxes,fontsize=12, fontweight='bold', va='top')


ax[0].legend()

ax[1].plot(ts_boxes_gt27['time'].isel(time=slice(2,tlen)), 
           ts_boxes_gt27['phytoC_TOT_zint'].isel(time=slice(2,tlen))-ds_AZ_means['mean_tot_phyto'], 
           color='green', label='total phytoplankton')
ax[1].plot(ts2_boxes_gt27['time'].isel(time=slice(2,tlen)), 
           ts2_boxes_gt27['phytoC_TOT_zint'].isel(time=slice(2,tlen))-ds_AZ_means2['mean_tot_phyto'], 
           color='lightgreen', label='total phytoplankton2')
ax[1].plot(ts3_boxes_gt27['time'].isel(time=slice(2,tlen)), 
           ts3_boxes_gt27['phytoC_TOT_zint'].isel(time=slice(2,tlen))-ds_AZ_means3['mean_tot_phyto'], 
           color='turquoise', label='total phytoplankton3')


ax[1].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[1].set_xlabel('Year')
ax[1].legend()

ax[2].plot(ts_boxes_gt27['time'].isel(time=slice(2,tlen)), 
           ts_boxes_gt27['diatC_zint'].isel(time=slice(2,tlen))-ds_AZ_means['mean_diat'], 
           color='darkgreen', label='diatoms')
ax[2].plot(ts2_boxes_gt27['time'].isel(time=slice(2,tlen)), 
           ts2_boxes_gt27['diatC_zint'].isel(time=slice(2,tlen))-ds_AZ_means2['mean_diat'], 
           color='orange', label='diatoms2')
ax[2].plot(ts3_boxes_gt27['time'].isel(time=slice(2,tlen)), 
           ts3_boxes_gt27['diatC_zint'].isel(time=slice(2,tlen))-ds_AZ_means3['mean_diat'], 
           color='blue', label='diatoms3')


#ax[2].set_ylabel('diatoms (mmol m$^{-2}$)')
ax[2].set_xlabel('Year')
ax[2].legend();

# %%
style.use('ggplot')
fig, ax = plt.subplots(nrows=4,ncols=1,figsize=(10,12))
fig.suptitle('Southern Ocean, ${\sigma}_{\Theta}$ > 27 surface outcrop, integrated mean biomass')
ax[0].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[0].plot(ts_boxes_gt27['time'].isel(time=slice(2,tlen)), 
         ts_boxes_gt27['zoo4C_zint'].isel(time=slice(2,tlen))- ds_AZ_means['mean_macrozoo'], 
         color='red', label='high zoo4 mort')
ax[0].plot(ts2_boxes_gt27['time'].isel(time=slice(2,tlen)), 
         ts2_boxes_gt27['zoo4C_zint'].isel(time=slice(2,tlen))- ds_AZ_means2['mean_macrozoo'], 
         color='green', label='lower zoo4 mort')
ax[0].plot(ts3_boxes_gt27['time'].isel(time=slice(2,tlen)), 
         ts3_boxes_gt27['zoo4C_zint'].isel(time=slice(2,tlen))- ds_AZ_means3['mean_macrozoo'], 
         color='blue', label='lowest zoo4 mort')
# ax[0].plot(ts4_boxes_gt27['time'].isel(time=slice(2,tlen)), 
#          ts4_boxes_gt27['zoo4C_zint'].isel(time=slice(2,tlen))- ds_AZ_means4['mean_macrozoo'], 
#          color='orange', label='lowlin, highquad zoo4 mort')
ax[0].text(0.02, 0.95, 'Macrozooplankton', transform=ax[0].transAxes,fontsize=12, fontweight='bold', va='top')
ax[0].legend()

ax[1].plot(ts_boxes_gt27['time'].isel(time=slice(2,tlen)), 
           ts_boxes_gt27['zoo3C_zint'].isel(time=slice(2,tlen)) - ds_AZ_means['mean_mesozoo'], 
           color='orange', label='high zoo4 mort')
ax[1].plot(ts2_boxes_gt27['time'].isel(time=slice(2,tlen)), 
           ts2_boxes_gt27['zoo3C_zint'].isel(time=slice(2,tlen)) - ds_AZ_means2['mean_mesozoo'], 
           color='gold', label='lower zoo4 mort')
ax[1].plot(ts3_boxes_gt27['time'].isel(time=slice(2,tlen)), 
           ts3_boxes_gt27['zoo3C_zint'].isel(time=slice(2,tlen)) - ds_AZ_means3['mean_mesozoo'], 
           color='red', label='lowest zoo4 mort')
ax[1].text(0.02, 0.95, 'Mesozooplankton', transform=ax[1].transAxes,fontsize=12, fontweight='bold', va='top')
ax[1].set_xlabel('Year')
ax[1].legend()


ax[2].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[2].plot(ts_boxes_gt27['time'].isel(time=slice(2,tlen)), 
         (ts_boxes_gt27['zoo1C_zint'].isel(time=slice(2,tlen))+ts_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))) - ds_AZ_means['mean_microzoo'], 
         color='magenta', label='high zoo4 mort')
ax[2].plot(ts2_boxes_gt27['time'].isel(time=slice(2,tlen)), 
         (ts2_boxes_gt27['zoo1C_zint'].isel(time=slice(2,tlen))+ts2_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))) - ds_AZ_means2['mean_microzoo'], 
         color='purple', label='lower zoo4 mort')
ax[2].plot(ts3_boxes_gt27['time'].isel(time=slice(2,tlen)), 
         (ts3_boxes_gt27['zoo1C_zint'].isel(time=slice(2,tlen))+ts3_boxes_26to27['zoo2C_zint'].isel(time=slice(2,tlen))) - ds_AZ_means3['mean_microzoo'], 
         color='green', label='lowest zoo4 mort')
ax[2].text(0.02, 0.95, 'Microzooplankton', transform=ax[2].transAxes,fontsize=12, fontweight='bold', va='top')
ax[2].legend()


ax[3].plot(ts_boxes_gt27['time'].isel(time=slice(2,tlen)), 
           ts_boxes_gt27['phytoC_TOT_zint'].isel(time=slice(2,tlen))-ds_AZ_means['mean_tot_phyto'], 
           color='green', label='high zoo4 mort')
ax[3].plot(ts2_boxes_gt27['time'].isel(time=slice(2,tlen)), 
           ts2_boxes_gt27['phytoC_TOT_zint'].isel(time=slice(2,tlen))-ds_AZ_means2['mean_tot_phyto'], 
           color='lightgreen', label='lower zoo4 mort')
ax[3].plot(ts3_boxes_gt27['time'].isel(time=slice(2,tlen)), 
           ts3_boxes_gt27['phytoC_TOT_zint'].isel(time=slice(2,tlen))-ds_AZ_means3['mean_tot_phyto'], 
           color='blue', label='lowest zoo4 mort')
ax[3].text(0.02, 0.95, 'Phytoplankton', transform=ax[3].transAxes,fontsize=12, fontweight='bold', va='top')

ax[3].set_ylabel('Biomass (mmol m$^{-2}$)')
ax[3].set_xlabel('Year')
ax[3].legend();

# %% [markdown]
# ### Look at the surface chlorophyll between the two runs

# %%
mean_chl = ts_boxes_26to27['tot_chl_surf'].isel(time=slice(2,62)).mean(dim='time')
mean_chl2 = ts2_boxes_26to27['tot_chl_surf'].isel(time=slice(2,25)).mean(dim='time')
mean_chl3 = ts3_boxes_26to27['tot_chl_surf'].isel(time=slice(2,25)).mean(dim='time')

# %%
style.use('default')
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(10,4))
ax.set_ylabel('Surface chlorophyll (mg m$^{-3}$)')
ax.plot(ts_boxes_26to27['time'].isel(time=slice(2,62)), 
         ts_boxes_26to27['tot_chl_surf'].isel(time=slice(2,62))-mean_chl, 
         color='red', label='chlorophyll')
ax.plot(ts2_boxes_26to27['time'].isel(time=slice(2,25)), 
         ts2_boxes_26to27['tot_chl_surf'].isel(time=slice(2,25))-mean_chl2, 
         color='magenta', label='chlorophyll2')
ax.plot(ts3_boxes_26to27['time'].isel(time=slice(2,25)), 
         ts3_boxes_26to27['tot_chl_surf'].isel(time=slice(2,25))-mean_chl3, 
         color='orange', label='chlorophyll3')
ax.legend();

# %%
mean_chl = ts_boxes_gt27['tot_chl_surf'].isel(time=slice(2,62)).mean(dim='time')
mean_chl2 = ts2_boxes_gt27['tot_chl_surf'].isel(time=slice(2,25)).mean(dim='time')
mean_chl3 = ts3_boxes_gt27['tot_chl_surf'].isel(time=slice(2,25)).mean(dim='time')

# %%
style.use('default')
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(10,4))
ax.set_ylabel('Surface chlorophyll (mg m$^{-3}$)')
ax.plot(ts_boxes_gt27['time'].isel(time=slice(2,62)), 
         ts_boxes_gt27['tot_chl_surf'].isel(time=slice(2,62))-mean_chl, 
         color='red', label='chlorophyll')
ax.plot(ts2_boxes_gt27['time'].isel(time=slice(2,25)), 
         ts2_boxes_gt27['tot_chl_surf'].isel(time=slice(2,25))-mean_chl2, 
         color='magenta', label='chlorophyll2')
ax.plot(ts3_boxes_gt27['time'].isel(time=slice(2,25)), 
         ts3_boxes_gt27['tot_chl_surf'].isel(time=slice(2,25))-mean_chl3, 
         color='orange', label='chlorophyll3')
ax.legend();
